# %%
import numpy as np
import pandas as pd
import seaborn as snp

# %%
data = pd.read_csv('zomato.csv')

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %% [markdown]
#             THE OPERATIONS TO PERFORM
# Deleting redundant columns.
# Renaming the columns.
# Dropping duplicates.
# Cleaning individual columns.
# Remove the NaN values from the dataset
# Check for some more Transformations

# %%
#deleting the redundant columns 

columns_to_keep = ['name','online_order', 'book_table', 'rate','cuisines', 'approx_cost(for two people)']

columns_to_drop = ['url', 'address','phone', 'location','votes','rest_type','cuisines' ,'reviews_list', 'menu_item',
       'listed_in(type)', 'listed_in(city)']

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
len(columns_to_drop)
# Out:
# 11

# %%
len(columns_to_keep)
# Out:
# 6

# %%
#filtering the data  [[]] is used so that we can filter multiple column names

data[['name','url','rate','cuisines']]
# Out:
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# 3                                  Addhuri Udupi Bhojana
# 4                                          Grand Village
# ...                                                  ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...
# 51713                           Vinod Bar And Restaurant
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                       The Nest - The Den Bengaluru
#
#                                                      url    rate  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...   4.1/5
# 1      https://www.zomato.com/bangalore/spice-elephan...   4.1/5
# 2      https://www.zomato.com/SanchurroBangalore?cont...   3.8/5
# ...

# %%
md_dt = data[columns_to_keep]

# %%
md_dt #now we can columns to keep
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                cuisines  \
# ...

# %%
#Columns to drop
data[columns_to_drop]
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#dropping columns are
data.drop(columns_to_drop,axis=1,inplace=True)

# %%
data  #as before whole data has 17 columns now it has only 6 columns
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# NOW RENAMING THE COLUMNS

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'dish_liked',
#        'approx_cost(for two people)'],
#       dtype='object')

# %%
#checking for one column first   
#converting first letter of word into capital
data.columns[0].capitalize()
# Out:
# 'Name'

# %%
#now applying for all columns as converting the first word into capital
new_data_columns=[]
for i in data.columns:
    new_data_columns.append(i.capitalize())

# %%
new_data_columns
# Out:
# ['Name',
#  'Online_order',
#  'Book_table',
#  'Rate',
#  'Dish_liked',
#  'Approx_cost(for two people)']

# %%
data.columns = new_data_columns    #now assigning to main data

# %%
data   # hence all first word of columns are converted into the Uppercase letter
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %% [markdown]
# REMOVING THE DUPLICATES

# %%
data.columns
# Out:
# Index(['Name', 'Online_order', 'Book_table', 'Rate', 'Dish_liked',
#        'Approx_cost(for two people)'],
#       dtype='object')

# %%
#checking how many duplicates are there
data.duplicated().sum()
# Out:
# np.int64(32808)

# %%
data.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
data
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %%
#dropping all the duplicated values
data.drop_duplicates(inplace=True)

# %%
#hence no duplicated values are shown
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data       #also 51717 rows are decreased to 18909 values
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51631                                      Just Parathas           No
# 51632                                   SeeYa Restaurant           No
# 51641                                      Andhra Spices           No
# 51677                                            Bhagini           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %% [markdown]
# REMOVING THE NAN VALUES FROM THE DATASET

# %%
#looking at the null values
data.isnull().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rate                            2418
# Dish_liked                     10587
# Approx_cost(for two people)      140
# dtype: int64

# %%
data
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51631                                      Just Parathas           No
# 51632                                   SeeYa Restaurant           No
# 51641                                      Andhra Spices           No
# 51677                                            Bhagini           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %%
#dropping all the NAN values from dataset
data.dropna(inplace=True)

# %%
#HENCE ALL THE NULL VALUES ARE REMOVED
data.isnull().sum()
# Out:
# Name                           0
# Online_order                   0
# Book_table                     0
# Rate                           0
# Dish_liked                     0
# Approx_cost(for two people)    0
# dtype: int64

# %%
#even the rows are decresed from 18909 to 8250
data
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51611                                    Chung Wah           No         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
#          Rate                                         Dish_liked  \
# ...

# %%
#Looking the index it got shuffled in order to extract it becomes difficult

data.reset_index(inplace=True)

# %%
data
# Out:
#       index                                         Name Online_order  \
# 0         0                                        Jalsa          Yes
# 1         1                               Spice Elephant          Yes
# 2         2                              San Churro Cafe          Yes
# 3         3                        Addhuri Udupi Bhojana           No
# 4         4                                Grand Village           No
# ...     ...                                          ...          ...
# 8245  51611                                    Chung Wah           No
# 8246  51617                              Breakfast House           No
# 8247  51620                               Fujian Express          Yes
# 8248  51628  Nook - Aloft Bengaluru Cessna Business Park           No
# 8249  51677                                      Bhagini           No
#
#      Book_table    Rate                                         Dish_liked  \
# ...

# %%
#now in that dataset index is extra column which we dont require
data.drop('index',axis=1,inplace=True)

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#         Rate                                         Dish_liked  \
# ...

# %% [markdown]
# CLEANING INDIVIDUAL COLUMNS

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#         Rate                                         Dish_liked  \
# ...

# %%
#we are gonna change of the Rate column
data.loc[1,'Rate']   #well it is in the string format
# Out:
# '4.1/5'

# %%
type(data.loc[1,'Rate']) #checking the datatype
# Out:
# str

# %%
#now i want to remove the extra spaces between the rate for example
data.loc[8248,'Rate']   #as you can see there is extra space before /
# Out:
# '4.2 /5'

# %%
#removing the extra space by replace the extra space
data['Rate']=data['Rate'].str.replace(' ','')

# %%
data.loc[8248,'Rate']
# Out:
# '4.2/5'

# %%
#NOW REMOVING THE / 
data['Rate'].str.replace('/',' out of ')
# Out:
# 0       4.1 out of 5
# 1       4.1 out of 5
# 2       3.8 out of 5
# 3       3.7 out of 5
# 4       3.8 out of 5
#             ...
# 8245    2.5 out of 5
# 8246    3.6 out of 5
# 8247    3.8 out of 5
# 8248    4.2 out of 5
# 8249    2.5 out of 5
# Name: Rate, Length: 8250, dtype: object

# %%
#now assiging to the real dataset (DATA)
data['Rate']=data['Rate'].str.replace('/',' out of ')

# %%
#hence all the data is been changed
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#               Rate                                         Dish_liked  \
# ...

# %%
data.to_excel('Zomata_Clean_Data.xlsx')

# %% [markdown]
# EXTRA WORK OPTIONAL AND ITS ADDITIONAL

# %%
data.columns
# Out:
# Index(['Name', 'Online_order', 'Book_table', 'Rate', 'Dish_liked',
#        'Approx_cost(for two people)'],
#       dtype='object')

# %%
snp.boxplot(data['Approx_cost(for two people)'])
# Out:
# <Axes: ylabel='Approx_cost(for two people)'>
